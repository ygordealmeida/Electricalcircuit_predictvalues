# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np
# Abrir o arquivo para leitura binária ('rb')
with open('historico_200', 'rb') as file:
    # Carregar os dados do arquivo usando pickle
    loaded_history = pickle.load(file)

# Agora, 'loaded_history' contém os dados carregados do arquivo
#print(loaded_history)

# Extraia os dados do histórico
acc = loaded_history['accuracy']
val_acc = loaded_history['val_accuracy']
loss = loaded_history['loss']
val_loss = loaded_history['val_loss']
epochs = range(1, len(acc) + 1)

# Plote os gráficos
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import pickle
import matplotlib.pyplot as plt

# Abrir o arquivo para leitura binária ('rb')
with open('historico_250', 'rb') as file:
    # Carregar os dados do arquivo usando pickle
    loaded_history250 = pickle.load(file)
with open('historico_200', 'rb') as file:
    # Carregar os dados do arquivo usando pickle
    loaded_history200 = pickle.load(file)
with open('historico_150', 'rb') as file:
    # Carregar os dados do arquivo usando pickle
    loaded_history150 = pickle.load(file)
with open('historico_125', 'rb') as file:
    # Carregar os dados do arquivo usando pickle
    loaded_history125 = pickle.load(file)
with open('historico_100', 'rb') as file:
    # Carregar os dados do arquivo usando pickle
    loaded_history100 = pickle.load(file)

# Agora, 'loaded_history' contém os dados carregados do arquivo
#print(loaded_history)
# Extraia os dados do histórico

#acc = loaded_history250['accuracy']
#val_acc = loaded_history250['val_accuracy']

loss250 = loaded_history250['loss']
val_loss250 = loaded_history250['val_loss']

loss200 = loaded_history200['loss']
val_loss200 = loaded_history200['val_loss']

loss150 = loaded_history150['loss']
val_loss150 = loaded_history150['val_loss']

loss125 = loaded_history125['loss']
val_loss125 = loaded_history125['val_loss']

loss100 = loaded_history100['loss']
val_loss100 = loaded_history100['val_loss']

epochs = range(1, len(loss) + 1)

# Plote os gráficos
#plt.plot(epochs, loss250, 'r', label='Training loss')
#plt.plot(epochs, val_loss250, 'b', label='Validation loss 250px')
plt.plot(epochs, val_loss200, 'r', label='Erro de validação 200px')
plt.plot(epochs, val_loss150, 'g', label='Erro de validação 150px')
plt.plot(epochs, val_loss125, 'm', label='Erro de validação 125px')
plt.plot(epochs, val_loss100, 'k', label='Erro de validação 100px')

plt.title('Erro de validação')
plt.xlabel('Epócas')
array_arange = np.arange(2.5, 0.01, -0.3)
plt.yticks(array_arange)
plt.ylabel('Erro')
plt.legend()
plt.grid()

plt.show()

# %%
print (loaded_history250.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
